# %% [markdown]
# ## Quick Sort

# %%
import numpy as np
import random

# %%
#generate a random array
random.seed(42)
arr=[random.randint(0,100) for _ in range(10)]
origin_arr=arr.copy()

def quick_sort(arr,left,right):
    if (left>=right): return
    pivot=arr[left]
    i=left
    j=right
    while (i<j):
        while (i<j and arr[j]>=pivot): j-=1
        if (i<j): 
            arr[i]=arr[j]
            i+=1
        while (i<j and arr[i]<=pivot): i+=1
        if (i<j):
            arr[j]=arr[i]
            j-=1
    arr[i]=pivot
    pivot_idx=i
    quick_sort(arr,left,pivot_idx-1)
    quick_sort(arr,pivot_idx+1,right)
    return arr

left=0
right=len(arr)-1
sorted_arr=quick_sort(arr,left,right)
print("Original array:", origin_arr)
print("Sorted array:", sorted_arr)
# Out:
# Original array: [81, 14, 3, 94, 35, 31, 28, 17, 94, 13]
# Sorted array: [3, 13, 14, 17, 28, 31, 35, 81, 94, 94]

# %%
def quick_sort_hoare(left,right,arr):
    if (left>=right):
        return
    i,j=left,right
    pivot=arr[(left+right)//2]
    while(i<=j):
        while (i<=j and arr[i]<pivot):
            i+=1
        while (i<=j and arr[j]>pivot):
            j-=1
        if (i<=j):
            arr[i],arr[j]=arr[j],arr[i]
            i+=1
            j-=1


    quick_sort_hoare(left,j,arr)
    quick_sort_hoare(i,right,arr)

    return arr

arr=[random.randint(0,100) for _ in range(10)]
print("Original array:", arr)
quick_sort_hoare(0,len(arr)-1,arr)
print("Sorted array:", arr)
# Out:
# Original array: [58, 81, 46, 20, 47, 45, 26, 85, 34, 89]
# Sorted array: [20, 26, 34, 45, 46, 47, 58, 81, 85, 89]
